# %%
#svm
#pc=1
#pf = 0.35
#C=0.01
#kernel = poly

# %%
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np
import os
import pandas as pd

# %%
base_dir = '../data/'

# %%
files = os.listdir(base_dir)
files = filter(lambda y: map(lambda x: x.split('.'), [y])[0][-1:][0]== 'realrank' , files)

# %%
cvs = {}
for f in files:
    with open(base_dir+f) as handle:
        a = handle.readline().split(',')
        cvs[f] = (float(a[0]), float(a[1]))
        
tops_ba = sorted(cvs.items(), key=lambda a: a[1][0], reverse=True)
tops_f1 = sorted(cvs.items(), key=lambda a: a[1][1], reverse=True)

# %%
tops_ba
# Out:
# [('steam_0_0.25_model_svm_C_1_kernel_poly.realrank',
#   (0.7467422969187676, 0.5569516686497819)),
#  ('steam_0_0_model_svm_C_1_kernel_poly.realrank',
#   (0.7432549019607844, 0.5627859540240561)),
#  ('steam_1_0.25_model_knn_nneigh_3.realrank',
#   (0.7423137254901961, 0.5739358253193603)),
#  ('steam_0_0.25_model_lr_C_0.01.realrank',
#   (0.7419607843137255, 0.5638265368251303)),
#  ('steam_025_0_model_svm_C_1_kernel_poly.realrank',
#   (0.7415966386554622, 0.5521988719960939)),
#  ('steam_1_0.25_model_svm_C_1_kernel_poly.realrank',
#   (0.7395490196078431, 0.5603726299286063)),
#  ('steam_1_0.25_model_knn_nneigh_1.realrank',
#   (0.7390280112044818, 0.566200236798063)),
#  ('steam_1_0.25_model_svm_C_1_kernel_linear.realrank',
#   (0.7388823529411765, 0.5642397995024534)),
#  ('steam_05_0.5_model_knn_nneigh_7.realrank',
#   (0.7388683473389357, 0.5656376020134729)),
#  ('steam_1_0.75_model_lr_C_0.01.realrank',
#   (0.7378627450980392, 0.5620870301975908)),
#  ('steam_1_0.5_model_knn_nneigh_3.realrank',
#   (0.7376806722689075, 0.5564211872718605)),
#  ('steam_075_0.5_model_knn_nneigh_1.realrank',
#   (0.7367394957983193, 0.5615032839800642)),
#  ('steam_05_0.25_model_knn_nneigh_7.realrank',
#   (0.7363753501400561, 0.5567285591753096)),
#  ('steam_025_0.5_model_svm_C_1_kernel_poly.realrank',
#   (0.7361568627450981, 0.5488800378414798)),
#  ('steam_05_0.75_model_knn_nneigh_7.realrank',
#   (0.7360392156862745, 0.5627520021313249)),
#  ('steam_075_0.75_model_knn_nneigh_3.realrank',
#   (0.7358711484593836, 0.5593609562250536)),
#  ('steam_0_0.5_model_lr_C_1.realrank',
#   (0.7357647058823529, 0.5652555593072922)),
#  ('steam_05_0.75_model_lr_C_0.01.realrank',
#   (0.7356414565826331, 0.555418162083926)),
#  ('steam_0_0_model_knn_nneigh_1.realrank',
#   (0.7347703081232493, 0.5568691597479176)),
#  ('steam_025_0.5_model_knn_nneigh_1.realrank',
#   (0.7345042016806722, 0.5512794380842915)),
#  ('steam_05_0.5_model_lr_C_0.01.realrank',
#   (0.7343557422969187, 0.5602031993139803)),
#  ('steam_025_0_model_svm_C_1_kernel_linear.realrank',
#   (0.7342773109243697, 0.5492867637418752)),
#  ('steam_0_0.5_model_svm_C_1_kernel_poly.realrank',
#   (0.733893557422969, 0.5452217737207169)),
#  ('steam_05_0.5_model_knn_nneigh_3.realrank',
#   (0.7338571428571429, 0.5568691827992758)),
#  ('steam_0_0.5_model_lr_C_0.1.realrank',
#   (0.7336414565826331, 0.5642667299928406)),
#  ('steam_05_0.25_model_knn_nneigh_3.realrank',
#   (0.7336274509803922, 0.5585687105391691)),
#  ('steam_025_0.5_model_knn_nneigh_3.realrank',
#   (0.7335686274509805, 0.5590835437388051)),
#  ('steam_0_1_model_lr_C_0.01.realrank',
#   (0.7335378151260504, 0.5536982223536006)),
#  ('steam_1_0.5_model_svm_C_1_kernel_poly.realrank',
#   (0.7334117647058823, 0.5460941743319012)),
#  ('steam_05_0.25_model_svm_C_1_kernel_linear.realrank',
#   (0.7332380952380952, 0.5502894808426049)),
#  ('steam_1_0.5_model_lr_C_0.1.realrank',
#   (0.7331680672268908, 0.5486510377089494)),
#  ('steam_1_0.75_model_knn_nneigh_3.realrank',
#   (0.732983193277311, 0.5618173367441653)),
#  ('steam_05_0.25_model_svm_C_1_kernel_poly.realrank',
#   (0.7328487394957983, 0.5472038844700851)),
#  ('steam_0_0_model_knn_nneigh_3.realrank',
#   (0.7327731092436975, 0.5530511732778355)),
#  ('steam_1_0.25_model_lr_C_0.01.realrank',
#   (0.7326106442577032, 0.5554368056780834)),
#  ('steam_075_0.25_model_knn_nneigh_1.realrank',
#   (0.7324957983193278, 0.5498402904138595)),
#  ('steam_075_0.5_model_lr_C_0.01.realrank',
#   (0.7318039215686275, 0.5559663271558433)),
#  ('steam_025_0.25_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7317703081232493, 0.5392588049332235)),
#  ('steam_05_0_model_svm_C_1_kernel_linear.realrank',
#   (0.7317422969187676, 0.5373040855939907)),
#  ('steam_0_0.25_model_knn_nneigh_1.realrank',
#   (0.7317114845938375, 0.550889584773553)),
#  ('steam_0_0_model_knn_nneigh_7.realrank',
#   (0.7315966386554622, 0.5501812847890931)),
#  ('steam_1_0_model_svm_C_1_kernel_rbf.realrank',
#   (0.731450980392157, 0.5556659515423957)),
#  ('steam_075_0.5_model_knn_nneigh_3.realrank',
#   (0.7314397759103641, 0.5538798345972104)),
#  ('steam_025_0_model_knn_nneigh_7.realrank',
#   (0.7311596638655462, 0.5540855912257376)),
#  ('steam_05_0.75_model_knn_nneigh_1.realrank',
#   (0.7310952380952381, 0.5324283285740833)),
#  ('steam_025_0.25_model_lr_C_0.01.realrank',
#   (0.7310280112044818, 0.5516617781195786)),
#  ('steam_025_0.25_model_lr_C_1.realrank',
#   (0.7310280112044818, 0.5505996612083568)),
#  ('steam_05_0.5_model_svm_C_1_kernel_linear.realrank',
#   (0.7310224089635854, 0.5473082046440494)),
#  ('steam_075_0.75_model_knn_nneigh_7.realrank',
#   (0.7310000000000001, 0.5398899730010486)),
#  ('steam_1_0_model_knn_nneigh_1.realrank',
#   (0.7309831932773109, 0.5488457529544115)),
#  ('steam_05_0_model_svm_C_1_kernel_poly.realrank',
#   (0.7308851540616247, 0.5477854376655281)),
#  ('steam_05_0.25_model_lr_C_1.realrank',
#   (0.7307675070028011, 0.5466865458095574)),
#  ('steam_05_0.5_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7304845938375351, 0.5430087718833749)),
#  ('steam_075_0.5_model_knn_nneigh_7.realrank',
#   (0.7304593837535014, 0.5595697001123499)),
#  ('steam_075_0.25_model_knn_nneigh_3.realrank',
#   (0.7303193277310923, 0.5482578783427203)),
#  ('steam_0_0_model_svm_C_1_kernel_linear.realrank',
#   (0.7302577030812325, 0.5486479756804193)),
#  ('steam_025_0.25_model_knn_nneigh_7.realrank',
#   (0.730218487394958, 0.5480858735091937)),
#  ('steam_1_0_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7301400560224088, 0.5351138715212425)),
#  ('steam_075_0.75_model_lr_C_1.realrank',
#   (0.7300896358543417, 0.54540118541213)),
#  ('steam_025_0.5_model_knn_nneigh_7.realrank',
#   (0.7300112044817928, 0.5547869932614717)),
#  ('steam_075_0.25_model_lr_C_0.01.realrank',
#   (0.7300028011204482, 0.5473975089585121)),
#  ('steam_0_0.5_model_lr_C_0.01.realrank',
#   (0.7299775910364146, 0.5565327253461214)),
#  ('steam_05_0.75_model_knn_nneigh_3.realrank',
#   (0.7299579831932773, 0.5375368800651381)),
#  ('steam_075_0_model_lr_C_0.01.realrank',
#   (0.7297955182072828, 0.5347331163136031)),
#  ('steam_075_0_model_svm_C_1_kernel_linear.realrank',
#   (0.7297198879551821, 0.538199176522839)),
#  ('steam_025_0_model_svm_C_1_kernel_rbf.realrank',
#   (0.7295126050420169, 0.5420115672266682)),
#  ('steam_1_0.75_model_lr_C_0.1.realrank',
#   (0.7295070028011205, 0.5514178682666421)),
#  ('steam_025_0.5_model_lr_C_1.realrank',
#   (0.7294845938375351, 0.5445931512918954)),
#  ('steam_025_0.25_model_knn_nneigh_1.realrank',
#   (0.7294033613445379, 0.545669953199104)),
#  ('steam_075_0.25_model_svm_C_1_kernel_poly.realrank',
#   (0.7293949579831933, 0.5486986114452819)),
#  ('steam_05_0.5_model_lr_C_0.1.realrank',
#   (0.729310924369748, 0.5530982566056203)),
#  ('steam_025_0.75_model_lr_C_0.1.realrank',
#   (0.7292717086834734, 0.5456005485718435)),
#  ('steam_025_0_model_lr_C_0.01.realrank',
#   (0.7292464985994397, 0.558521781391822)),
#  ('steam_05_0.25_model_lr_C_0.1.realrank',
#   (0.7289271708683474, 0.5413297006522159)),
#  ('steam_025_0.75_model_lr_C_0.01.realrank',
#   (0.7288459383753502, 0.5560550070844188)),
#  ('steam_025_0.25_model_lr_C_0.1.realrank',
#   (0.7288291316526612, 0.5474706613616658)),
#  ('steam_05_0.5_model_knn_nneigh_1.realrank',
#   (0.7288095238095238, 0.5550580635604825)),
#  ('steam_05_0.5_model_lr_C_1.realrank',
#   (0.7288039215686275, 0.5474819374220617)),
#  ('steam_05_0_model_knn_nneigh_1.realrank',
#   (0.7287983193277311, 0.5441051708411841)),
#  ('steam_05_0_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7287815126050421, 0.5358487052688534)),
#  ('steam_05_0.5_model_svm_C_1_kernel_rbf.realrank',
#   (0.7287226890756303, 0.5422161026868738)),
#  ('steam_05_0.25_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7287086834733894, 0.5402165422071008)),
#  ('steam_1_0.75_model_lr_C_1.realrank',
#   (0.7287086834733894, 0.5505834766479054)),
#  ('steam_1_0_model_svm_C_1_kernel_linear.realrank',
#   (0.7286498599439776, 0.5478771580808213)),
#  ('steam_025_0_model_knn_nneigh_3.realrank',
#   (0.7285742296918768, 0.5470967445253159)),
#  ('steam_0_0.25_model_svm_C_1_kernel_linear.realrank',
#   (0.7285742296918767, 0.5430246667973018)),
#  ('steam_1_0.5_model_knn_nneigh_7.realrank',
#   (0.7285042016806723, 0.5511497004775037)),
#  ('steam_075_0.5_model_svm_C_1_kernel_rbf.realrank',
#   (0.7284649859943977, 0.5428579280110843)),
#  ('steam_05_0.5_model_svm_C_1_kernel_poly.realrank',
#   (0.7284621848739496, 0.5503404536773703)),
#  ('steam_025_0_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7283361344537814, 0.5394739987464445)),
#  ('steam_025_0.25_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7282605042016808, 0.5349309406445529)),
#  ('steam_1_0.25_model_lr_C_0.1.realrank',
#   (0.7282100840336135, 0.5621816218708958)),
#  ('steam_1_0_model_knn_nneigh_7.realrank',
#   (0.7281456582633055, 0.5615252011601343)),
#  ('steam_025_0_model_lr_C_1.realrank',
#   (0.7281008403361344, 0.5524057827679425)),
#  ('steam_1_0.25_model_lr_C_1.realrank',
#   (0.7278683473389356, 0.544842169956125)),
#  ('steam_05_0.25_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7278403361344539, 0.5353158447607328)),
#  ('steam_075_0.25_model_lr_C_1.realrank',
#   (0.7277591036414566, 0.5384067599956934)),
#  ('steam_1_0_model_lr_C_1.realrank', (0.7276890756302521, 0.5372101807269873)),
#  ('steam_05_0.75_model_lr_C_1.realrank',
#   (0.7276582633053221, 0.533427676986554)),
#  ('steam_1_0.75_model_svm_C_1_kernel_poly.realrank',
#   (0.7276274509803922, 0.5407339310986157)),
#  ('steam_05_0.25_model_knn_nneigh_1.realrank',
#   (0.7275546218487394, 0.5417923951189672)),
#  ('steam_0_0.25_model_lr_C_0.1.realrank',
#   (0.7274817927170868, 0.5442281310262453)),
#  ('steam_025_0.25_model_knn_nneigh_3.realrank',
#   (0.7274341736694678, 0.5511912949146992)),
#  ('steam_0_0.25_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7272941176470589, 0.5479720500595378)),
#  ('steam_05_0_model_svm_C_1_kernel_rbf.realrank',
#   (0.7272913165266107, 0.5341773089880749)),
#  ('steam_1_0.5_model_svm_C_1_kernel_linear.realrank',
#   (0.7272689075630253, 0.5377215225218854)),
#  ('steam_05_0.25_model_lr_C_0.01.realrank',
#   (0.7272352941176472, 0.5508282355167602)),
#  ('steam_075_0.5_model_svm_C_1_kernel_poly.realrank',
#   (0.7271652661064425, 0.5417745924182569)),
#  ('steam_075_0.25_model_knn_nneigh_7.realrank',
#   (0.7270700280112045, 0.548220860853905)),
#  ('steam_05_0_model_knn_nneigh_7.realrank',
#   (0.7270364145658263, 0.543111412857826)),
#  ('steam_075_0.5_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7270028011204481, 0.5410851263528749)),
#  ('steam_1_0.75_model_svm_C_1_kernel_linear.realrank',
#   (0.7269243697478991, 0.5339631721602606)),
#  ('steam_075_0.75_model_svm_C_0.1_kernel_linear.realrank',
#   (0.726921568627451, 0.5310510259254698)),
#  ('steam_05_0.75_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7269131652661065, 0.5378794279245362)),
#  ('steam_05_0.75_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7268655462184873, 0.536523070308606)),
#  ('steam_05_0_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7267619047619047, 0.5308431442813023)),
#  ('steam_075_0.5_model_lr_C_1.realrank',
#   (0.7265210084033613, 0.5419299081681163)),
#  ('steam_1_0.5_model_knn_nneigh_1.realrank',
#   (0.7262408963585434, 0.5430802783183054)),
#  ('steam_1_0_model_lr_C_0.1.realrank',
#   (0.7260588235294119, 0.5415111160202324)),
#  ('steam_05_0_model_lr_C_0.1.realrank',
#   (0.7260560224089636, 0.5408309917460354)),
#  ('steam_075_0_model_svm_C_1_kernel_poly.realrank',
#   (0.7260196078431372, 0.5442996759338222)),
#  ('steam_025_0_model_knn_nneigh_1.realrank',
#   (0.7259775910364146, 0.5424941463764993)),
#  ('steam_025_0_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7259439775910366, 0.5360017150099194)),
#  ('steam_025_0_model_lr_C_0.1.realrank',
#   (0.7259243697478992, 0.5535954396176541)),
#  ('steam_05_0.25_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7258851540616247, 0.5367040911821259)),
#  ('steam_025_0.5_model_lr_C_0.01.realrank',
#   (0.7256330532212887, 0.5448496300550449)),
#  ('steam_075_0_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7256218487394959, 0.5353228307369003)),
#  ('steam_1_0_model_knn_nneigh_3.realrank',
#   (0.7256022408963585, 0.5450794115598835)),
#  ('steam_05_0.5_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7256022408963585, 0.5384526556566954)),
#  ('steam_1_0.25_model_knn_nneigh_7.realrank',
#   (0.7255210084033614, 0.546721902988032)),
#  ('steam_0_0.25_model_svm_C_1_kernel_rbf.realrank',
#   (0.7255098039215687, 0.5392662673919302)),
#  ('steam_1_0_model_svm_C_1_kernel_poly.realrank',
#   (0.7254397759103642, 0.5531458678008706)),
#  ('steam_025_0.5_model_lr_C_0.1.realrank',
#   (0.7253837535014005, 0.5460456430816372)),
#  ('steam_0_0.25_model_knn_nneigh_3.realrank',
#   (0.7252801120448179, 0.5444880000525163)),
#  ('steam_1_0_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7252745098039216, 0.5501849509443051)),
#  ('steam_0_0.75_model_knn_nneigh_1.realrank',
#   (0.7252521008403361, 0.5361833932657731)),
#  ('steam_075_0_model_svm_C_0.1_kernel_linear.realrank',
#   (0.725249299719888, 0.534962061740204)),
#  ('steam_0_0.75_model_knn_nneigh_3.realrank',
#   (0.7252464985994397, 0.5409575425614956)),
#  ('steam_075_0_model_knn_nneigh_7.realrank',
#   (0.7252296918767507, 0.5334799270594192)),
#  ('steam_025_0.5_model_svm_C_1_kernel_linear.realrank',
#   (0.725156862745098, 0.5329507671390112)),
#  ('steam_075_0_model_lr_C_1.realrank', (0.725047619047619, 0.534774307406223)),
#  ('steam_1_0.5_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7250028011204482, 0.5385890111212852)),
#  ('steam_0_0.25_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7248795518207283, 0.5359692221185044)),
#  ('steam_1_0.25_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7248683473389357, 0.5473655761430128)),
#  ('steam_075_0_model_lr_C_0.1.realrank',
#   (0.724812324929972, 0.536133612397355)),
#  ('steam_1_0.75_model_svm_C_0.1_kernel_linear.realrank',
#   (0.724733893557423, 0.5312563685080696)),
#  ('steam_1_0_model_lr_C_0.01.realrank',
#   (0.7247282913165266, 0.5388015716605903)),
#  ('steam_05_0.75_model_lr_C_0.1.realrank',
#   (0.7244565826330532, 0.5424577076147828)),
#  ('steam_05_0.5_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7244425770308123, 0.5314064363947268)),
#  ('steam_0_0.25_model_lr_C_1.realrank',
#   (0.724344537815126, 0.543509275586407)),
#  ('steam_075_0.5_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7242549019607842, 0.5347029915294192)),
#  ('steam_075_0_model_svm_C_0.01_kernel_linear.realrank',
#   (0.724249299719888, 0.5328562079166084)),
#  ('steam_025_0.5_model_svm_C_1_kernel_rbf.realrank',
#   (0.7241148459383754, 0.5316160584289109)),
#  ('steam_0_0_model_svm_C_1_kernel_rbf.realrank',
#   (0.7240588235294118, 0.5406074264470067)),
#  ('steam_025_0.25_model_svm_C_1_kernel_linear.realrank',
#   (0.7240532212885153, 0.5328915476438226)),
#  ('steam_05_0.25_model_svm_C_1_kernel_rbf.realrank',
#   (0.7239243697478992, 0.5364846575739995)),
#  ('steam_075_0.25_model_svm_C_1_kernel_linear.realrank',
#   (0.7238515406162465, 0.5317607983168624)),
#  ('steam_025_0.25_model_svm_C_1_kernel_poly.realrank',
#   (0.7238291316526612, 0.5257648800644089)),
#  ('steam_1_0.5_model_lr_C_1.realrank',
#   (0.7237983193277311, 0.5437907701759181)),
#  ('steam_0_0.75_model_lr_C_0.01.realrank',
#   (0.7235994397759103, 0.5399686654120023)),
#  ('steam_1_0_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7235966386554622, 0.5377548534184691)),
#  ('steam_075_0_model_knn_nneigh_3.realrank',
#   (0.7235798319327731, 0.5349775590297278)),
#  ('steam_05_0_model_lr_C_0.01.realrank',
#   (0.7233865546218488, 0.5332863454932839)),
#  ('steam_0_0.25_model_knn_nneigh_7.realrank',
#   (0.7232717086834735, 0.5407029221935941)),
#  ('steam_1_0.5_model_svm_C_1_kernel_rbf.realrank',
#   (0.7226190476190475, 0.5333165949710067)),
#  ('steam_075_0.75_model_knn_nneigh_1.realrank',
#   (0.722560224089636, 0.5339333305342143)),
#  ('steam_075_0.75_model_lr_C_0.01.realrank',
#   (0.7225294117647059, 0.5421093954306411)),
#  ('steam_1_0.5_model_lr_C_0.01.realrank',
#   (0.7223165266106444, 0.5435103310139853)),
#  ('steam_075_0.5_model_svm_C_1_kernel_linear.realrank',
#   (0.722313725490196, 0.54562576603806)),
#  ('steam_025_0.5_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7221624649859943, 0.5278113631580019)),
#  ('steam_025_0.75_model_knn_nneigh_1.realrank',
#   (0.7221540616246498, 0.5347730160285971)),
#  ('steam_025_0.25_model_svm_C_1_kernel_rbf.realrank',
#   (0.7219915966386555, 0.5281175829652845)),
#  ('steam_025_0.5_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7219803921568627, 0.5339432741089525)),
#  ('steam_05_0_model_knn_nneigh_3.realrank',
#   (0.721672268907563, 0.5342653229123817)),
#  ('steam_075_0.25_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7216134453781514, 0.5379420325535503)),
#  ('steam_075_0.5_model_lr_C_0.1.realrank',
#   (0.721563025210084, 0.5437755046193959)),
#  ('steam_025_0.25_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7215602240896359, 0.5301848441505033)),
#  ('steam_075_0.25_model_svm_C_1_kernel_rbf.realrank',
#   (0.7212745098039216, 0.5352804525841943)),
#  ('steam_05_0_model_lr_C_1.realrank',
#   (0.7212296918767507, 0.5271283275935446)),
#  ('steam_075_0.25_model_lr_C_0.1.realrank',
#   (0.721064425770308, 0.530781958209743)),
#  ('steam_0_0_model_lr_C_1.realrank', (0.7209635854341737, 0.5464501382299807)),
#  ('steam_0_0_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7209019607843137, 0.532708137899998)),
#  ('steam_0_0.5_model_svm_C_1_kernel_linear.realrank',
#   (0.7206918767507002, 0.5424709936896168)),
#  ('steam_025_0_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7205042016806723, 0.5360850711925786)),
#  ('steam_1_0.75_model_svm_C_1_kernel_rbf.realrank',
#   (0.7204509803921568, 0.5348679067625042)),
#  ('steam_1_0.75_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7204117647058823, 0.5310658116118618)),
#  ('steam_075_0.75_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7203053221288516, 0.5359059721522127)),
#  ('steam_075_0.5_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7201288515406162, 0.5323127497247656)),
#  ('steam_1_0.5_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7200280112044817, 0.5290357252042107)),
#  ('steam_075_0.25_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7197142857142858, 0.5245581434528803)),
#  ('steam_025_0.75_model_lr_C_1.realrank',
#   (0.7196750700280112, 0.5364365904365904)),
#  ('steam_0_0.25_model_svm_C_0.1_kernel_poly.realrank',
#   (0.7194957983193278, 0.5290805180280213)),
#  ('steam_0_0.25_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7194117647058824, 0.5313160913393468)),
#  ('steam_05_0.75_model_svm_C_1_kernel_poly.realrank',
#   (0.7193669467787115, 0.5439535045004918)),
#  ('steam_1_0.25_model_svm_C_1_kernel_rbf.realrank',
#   (0.7187731092436974, 0.5257829127529587)),
#  ('steam_1_0.75_model_knn_nneigh_1.realrank',
#   (0.7184509803921569, 0.530552807654643)),
#  ('steam_0_0.5_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7184229691876751, 0.5363834804968933)),
#  ('steam_075_0.25_model_svm_C_0.1_kernel_linear.realrank',
#   (0.718280112044818, 0.5341409201946619)),
#  ('steam_0_0.75_model_svm_C_1_kernel_linear.realrank',
#   (0.7180784313725491, 0.5302201665759385)),
#  ('steam_025_0.75_model_knn_nneigh_3.realrank',
#   (0.7180644257703082, 0.5311081606731761)),
#  ('steam_0_0.75_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7179607843137256, 0.5375069112670836)),
#  ('steam_075_0.75_model_lr_C_0.1.realrank',
#   (0.7177591036414566, 0.5368441326938466)),
#  ('steam_1_0.25_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7177535014005602, 0.5231914035098467)),
#  ('steam_05_0_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7177226890756303, 0.5220122794367252)),
#  ('steam_075_0.75_model_svm_C_1_kernel_linear.realrank',
#   (0.7176498599439776, 0.5281496660096552)),
#  ('steam_05_0.75_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7176302521008404, 0.5213186474709903)),
#  ('steam_0_0_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7176162464985995, 0.5352815236895587)),
#  ('steam_075_0_model_svm_C_1_kernel_rbf.realrank',
#   (0.7173585434173668, 0.5230328143020853)),
#  ('steam_0_0.75_model_svm_C_1_kernel_rbf.realrank',
#   (0.7172380952380952, 0.5283629038659997)),
#  ('steam_075_0_model_knn_nneigh_1.realrank',
#   (0.7171400560224088, 0.5331598514723114)),
#  ('steam_025_0.75_model_knn_nneigh_7.realrank',
#   (0.717095238095238, 0.5345746470509279)),
#  ('steam_1_0.5_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7170868347338935, 0.5284714224454791)),
#  ('steam_05_0.75_model_svm_C_1_kernel_rbf.realrank',
#   (0.7169635854341737, 0.525047400849013)),
#  ('steam_0_0.75_model_svm_C_1_kernel_poly.realrank',
#   (0.7168263305322128, 0.5181927109948521)),
#  ('steam_0_0.75_model_knn_nneigh_7.realrank',
#   (0.7166946778711485, 0.5425679938955689)),
#  ('steam_0_0.75_model_lr_C_1.realrank',
#   (0.716593837535014, 0.5305236307729754)),
#  ('steam_0_0_model_svm_C_0.1_kernel_poly.realrank',
#   (0.7165714285714285, 0.5301640799713022)),
#  ('steam_0_0.5_model_knn_nneigh_3.realrank',
#   (0.7160364145658262, 0.5384342198402265)),
#  ('steam_0_0_model_lr_C_0.01.realrank',
#   (0.7159495798319329, 0.5326992019976021)),
#  ('steam_1_0.25_model_svm_C_0.1_kernel_linear.realrank',
#   (0.7158655462184874, 0.5280443867838825)),
#  ('steam_025_0.5_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7158095238095239, 0.5221209769261003)),
#  ('steam_075_0.75_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7154873949579832, 0.531364025441321)),
#  ('steam_1_0.75_model_knn_nneigh_7.realrank',
#   (0.7154145658263306, 0.5321329310406606)),
#  ('steam_0_0.75_model_lr_C_0.1.realrank',
#   (0.7151624649859942, 0.5313663556182205)),
#  ('steam_025_0.75_model_svm_C_1_kernel_rbf.realrank',
#   (0.714952380952381, 0.528214677826693)),
#  ('steam_0_0_model_lr_C_0.1.realrank',
#   (0.7146526610644258, 0.5329475023802053)),
#  ('steam_0_0.5_model_svm_C_1_kernel_rbf.realrank',
#   (0.7139551820728292, 0.519199529699103)),
#  ('steam_05_0.75_model_svm_C_1_kernel_linear.realrank',
#   (0.7136778711484593, 0.5194253075366531)),
#  ('steam_025_0.75_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7136638655462184, 0.5259142407311109)),
#  ('steam_0_0.5_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7127619047619047, 0.528222161935292)),
#  ('steam_1_0.75_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7126022408963586, 0.5212118434740021)),
#  ('steam_0_0.5_model_knn_nneigh_1.realrank',
#   (0.7124453781512605, 0.5280478496480304)),
#  ('steam_0_0_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7120476190476192, 0.5219004870909157)),
#  ('steam_0_0.75_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7119187675070029, 0.5182318961176202)),
#  ('steam_025_0.75_model_svm_C_1_kernel_linear.realrank',
#   (0.7119131652661064, 0.5185534768017247)),
#  ('steam_0_0.5_model_knn_nneigh_7.realrank',
#   (0.7116610644257703, 0.5332024769356366)),
#  ('steam_075_0.75_model_svm_C_1_kernel_rbf.realrank',
#   (0.710921568627451, 0.5241997799153466)),
#  ('steam_025_0.75_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.7099775910364147, 0.5184897363711991)),
#  ('steam_0_0.5_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7095042016806723, 0.52460857784975)),
#  ('steam_025_0.75_model_svm_C_0.1_kernel_linear.realrank',
#   (0.709403361344538, 0.5197123161061266)),
#  ('steam_075_0.75_model_svm_C_1_kernel_poly.realrank',
#   (0.7080308123249299, 0.5247611621282078)),
#  ('steam_025_0.75_model_svm_C_1_kernel_poly.realrank',
#   (0.7067058823529412, 0.5173294507702537)),
#  ('steam_0_0.75_model_svm_C_0.01_kernel_linear.realrank',
#   (0.7066022408963585, 0.5143941694439649)),
#  ('steam_025_1_model_lr_C_0.01.realrank',
#   (0.6998011204481793, 0.5106368073537885)),
#  ('steam_05_1_model_lr_C_0.01.realrank',
#   (0.6964985994397759, 0.5091487067925172)),
#  ('steam_075_1_model_lr_C_0.01.realrank',
#   (0.6877114845938375, 0.499257358201515)),
#  ('steam_0_1_model_lr_C_0.1.realrank',
#   (0.6839467787114847, 0.4934564347064347)),
#  ('steam_0_0.5_model_svm_C_0.1_kernel_poly.realrank',
#   (0.6777226890756303, 0.49085734617692117)),
#  ('steam_0_1_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.6706610644257702, 0.4699966495287552)),
#  ('steam_1_1_model_lr_C_0.01.realrank',
#   (0.6705714285714286, 0.4828643709304948)),
#  ('steam_025_1_model_lr_C_0.1.realrank',
#   (0.6657478991596639, 0.4693670786705564)),
#  ('steam_0_1_model_lr_C_1.realrank', (0.6625882352941177, 0.470665837755047)),
#  ('steam_1_1_model_lr_C_0.1.realrank',
#   (0.6618487394957983, 0.46469754078191405)),
#  ('steam_075_1_model_svm_C_0.01_kernel_linear.realrank',
#   (0.6594733893557423, 0.46171021463704387)),
#  ('steam_075_1_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.6572240896358543, 0.4538211348313321)),
#  ('steam_05_1_model_svm_C_0.01_kernel_linear.realrank',
#   (0.6551428571428571, 0.45678324941482834)),
#  ('steam_075_1_model_lr_C_0.1.realrank',
#   (0.6517507002801121, 0.44802559969757194)),
#  ('steam_075_1_model_svm_C_1_kernel_rbf.realrank',
#   (0.6501428571428572, 0.4523549684933207)),
#  ('steam_025_1_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.6467983193277311, 0.44753646023532345)),
#  ('steam_05_1_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.6445126050420168, 0.4430600181789489)),
#  ('steam_0_0.75_model_svm_C_0.1_kernel_poly.realrank',
#   (0.6427759103641456, 0.45543741180915776)),
#  ('steam_05_1_model_lr_C_0.1.realrank',
#   (0.6409635854341736, 0.44344287261832116)),
#  ('steam_025_1_model_svm_C_0.01_kernel_linear.realrank',
#   (0.6402128851540617, 0.4409320314714346)),
#  ('steam_0_1_model_svm_C_0.01_kernel_linear.realrank',
#   (0.6376470588235293, 0.4401071718067306)),
#  ('steam_1_1_model_svm_C_0.1_kernel_linear.realrank',
#   (0.6359635854341736, 0.43571137921712005)),
#  ('steam_0_1_model_svm_C_1_kernel_rbf.realrank',
#   (0.6322857142857143, 0.4313894765788902)),
#  ('steam_025_1_model_lr_C_1.realrank',
#   (0.631703081232493, 0.4252858696432865)),
#  ('steam_0_1_model_svm_C_0.1_kernel_linear.realrank',
#   (0.6313081232492996, 0.431225272394955)),
#  ('steam_025_1_model_svm_C_1_kernel_rbf.realrank',
#   (0.628532212885154, 0.4311950508247831)),
#  ('steam_1_0_model_svm_C_0.1_kernel_poly.realrank',
#   (0.6253193277310924, 0.44135107899873194)),
#  ('steam_075_1_model_lr_C_1.realrank',
#   (0.6248095238095238, 0.4078538420643684)),
#  ('steam_1_0.25_model_svm_C_0.1_kernel_poly.realrank',
#   (0.6238711484593839, 0.4376319750590948)),
#  ('steam_1_1_model_svm_C_1_kernel_rbf.realrank',
#   (0.6232352941176471, 0.4218052368822587)),
#  ('steam_05_1_model_svm_C_0.1_kernel_linear.realrank',
#   (0.6196554621848739, 0.41860723338598615)),
#  ('steam_05_1_model_lr_C_1.realrank',
#   (0.6190588235294118, 0.4117566813088035)),
#  ('steam_1_1_model_svm_C_0.1_kernel_rbf.realrank',
#   (0.6188235294117648, 0.4119892085366216)),
#  ('steam_05_1_model_svm_C_1_kernel_rbf.realrank',
#   (0.6166862745098038, 0.41355760052971746)),
#  ('steam_1_1_model_svm_C_0.01_kernel_linear.realrank',
#   (0.6163977591036415, 0.4123261781332917)),
#  ('steam_075_1_model_svm_C_0.1_kernel_linear.realrank',
#   (0.615156862745098, 0.416724688932043)),
#  ('steam_025_1_model_svm_C_0.1_kernel_linear.realrank',
#   (0.6144481792717087, 0.4181070864062561)),
#  ('steam_1_1_model_svm_C_1_kernel_linear.realrank',
#   (0.6126638655462185, 0.41238814376398186)),
#  ('steam_1_1_model_lr_C_1.realrank', (0.6119859943977591, 0.4004568163448508)),
#  ('steam_0_1_model_svm_C_1_kernel_linear.realrank',
#   (0.5931708683473389, 0.3906894325187008)),
#  ('steam_075_1_model_svm_C_1_kernel_linear.realrank',
#   (0.5862464985994398, 0.3848641796958217)),
#  ('steam_05_1_model_knn_nneigh_3.realrank',
#   (0.5803809523809523, 0.34233046531600475)),
#  ('steam_025_1_model_knn_nneigh_1.realrank',
#   (0.5785518207282913, 0.3413676155821229)),
#  ('steam_1_1_model_knn_nneigh_3.realrank',
#   (0.5761288515406162, 0.3177512292804647)),
#  ('steam_025_1_model_knn_nneigh_3.realrank',
#   (0.5750112044817928, 0.3385557733166187)),
#  ('steam_05_1_model_knn_nneigh_1.realrank',
#   (0.5701484593837536, 0.3370275691129271)),
#  ('steam_075_1_model_knn_nneigh_3.realrank',
#   (0.568156862745098, 0.3004735554300772)),
#  ('steam_0_1_model_knn_nneigh_7.realrank',
#   (0.5667058823529413, 0.2884039741934479)),
#  ('steam_05_1_model_knn_nneigh_7.realrank',
#   (0.5666638655462185, 0.3064713804713805)),
#  ('steam_1_1_model_svm_C_1_kernel_poly.realrank',
#   (0.5655826330532212, 0.27613224007692916)),
#  ('steam_075_1_model_knn_nneigh_1.realrank',
#   (0.5645042016806723, 0.3250153995806297)),
#  ('steam_05_1_model_svm_C_1_kernel_linear.realrank',
#   (0.5644873949579832, 0.359660835722521)),
#  ('steam_1_0.5_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5615574229691876, 0.39682092861396945)),
#  ('steam_05_0.5_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5609243697478992, 0.422752726201002)),
#  ('steam_05_0.5_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5598739495798319, 0.41512820512820514)),
#  ('steam_0_1_model_knn_nneigh_3.realrank',
#   (0.5587927170868348, 0.3082376394220472)),
#  ('steam_0_1_model_knn_nneigh_1.realrank',
#   (0.5581932773109244, 0.3212318844321723)),
#  ('steam_075_0_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5576330532212885, 0.4156080031080031)),
#  ('steam_025_0.25_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5570028011204482, 0.416517094017094)),
#  ('steam_1_0.75_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5570028011204482, 0.4183028083028083)),
#  ('steam_025_1_model_svm_C_1_kernel_linear.realrank',
#   (0.5545378151260504, 0.35309592429035647)),
#  ('steam_025_1_model_knn_nneigh_7.realrank',
#   (0.5541624649859943, 0.26666586578505613)),
#  ('steam_05_0.75_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5539915966386555, 0.4094193928676687)),
#  ('steam_025_0_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5537114845938376, 0.41237937689550586)),
#  ('steam_05_0.75_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5533613445378152, 0.4073504273504273)),
#  ('steam_075_0.75_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5514705882352942, 0.4107591754650578)),
#  ('steam_075_0_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5511204481792717, 0.4066486729644624)),
#  ('steam_0_0.75_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5507703081232493, 0.4073504273504273)),
#  ('steam_0_0.75_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5507703081232493, 0.4073504273504273)),
#  ('steam_1_1_model_knn_nneigh_1.realrank',
#   (0.5503781512605042, 0.305957528957529)),
#  ('steam_0_0_model_svm_C_0.01_kernel_poly.realrank',
#   (0.548249299719888, 0.4075228411435308)),
#  ('steam_0_0_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.548249299719888, 0.4075228411435308)),
#  ('steam_1_0_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5480392156862746, 0.4007303807303807)),
#  ('steam_025_0.5_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5478291316526611, 0.40512820512820513)),
#  ('steam_025_0_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5471988795518208, 0.40360042735042734)),
#  ('steam_05_0.25_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5467787114845939, 0.39891905480140777)),
#  ('steam_075_0.75_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5453781512605043, 0.4067970676666329)),
#  ('steam_025_0.75_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5450980392156863, 0.39602017568119263)),
#  ('steam_025_0.75_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5450980392156863, 0.39602017568119263)),
#  ('steam_0_0.25_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5449579831932774, 0.40168197815256634)),
#  ('steam_0_0.25_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5449579831932774, 0.40168197815256634)),
#  ('steam_0_0.5_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5449579831932774, 0.4022422022422022)),
#  ('steam_0_0.5_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5449579831932774, 0.4022422022422022)),
#  ('steam_05_0_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5446778711484594, 0.4041011276305394)),
#  ('steam_05_0_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5446778711484594, 0.4041011276305394)),
#  ('steam_025_0.5_model_svm_C_0.01_kernel_poly.realrank',
#   (0.544607843137255, 0.3986991345481911)),
#  ('steam_1_0.25_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5442577030812326, 0.408743601730979)),
#  ('steam_075_0.5_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5423669467787116, 0.39767563060245986)),
#  ('steam_075_0.5_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5423669467787116, 0.39767563060245986)),
#  ('steam_05_0.25_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5423669467787114, 0.39731379731379735)),
#  ('steam_1_1_model_knn_nneigh_7.realrank',
#   (0.5422577030812323, 0.22673440848498055)),
#  ('steam_025_0.25_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5413865546218488, 0.3961604790873084)),
#  ('steam_1_0_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5397058823529411, 0.39401709401709406)),
#  ('steam_1_0.75_model_svm_C_0.01_kernel_poly.realrank',
#   (0.538935574229692, 0.3922929560860595)),
#  ('steam_075_0.25_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5383753501400561, 0.3926334462183519)),
#  ('steam_1_0.5_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5380952380952382, 0.3946382120295164)),
#  ('steam_1_0.5_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5380952380952382, 0.3946382120295164)),
#  ('steam_075_1_model_knn_nneigh_7.realrank',
#   (0.5377759103641456, 0.21672196563500915)),
#  ('steam_1_0.25_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5371148459383754, 0.3926913364413364)),
#  ('steam_075_0.25_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5367647058823529, 0.39017094017094023)),
#  ('steam_05_1_model_svm_C_1_kernel_poly.realrank',
#   (0.530436974789916, 0.18523917259211378)),
#  ('steam_0_1_model_svm_C_1_kernel_poly.realrank',
#   (0.5226078431372547, 0.37583128641897684)),
#  ('steam_1_0.75_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5186862745098039, 0.37388767795729827)),
#  ('steam_025_1_model_svm_C_1_kernel_poly.realrank',
#   (0.5147450980392156, 0.37195653958645297)),
#  ('steam_0_1_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5068823529411765, 0.3681300181300181)),
#  ('steam_025_0.25_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_025_1_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5, 0.294017094017094)),
#  ('steam_0_1_model_svm_C_0.01_kernel_poly.realrank', (0.5, 0.294017094017094)),
#  ('steam_075_1_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5, 0.294017094017094)),
#  ('steam_025_0_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_075_1_model_svm_C_1_kernel_poly.realrank',
#   (0.5, 0.037037037037037035)),
#  ('steam_05_0.25_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_025_0.75_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_075_0.75_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_075_1_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_05_1_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5, 0.294017094017094)),
#  ('steam_1_1_model_svm_C_0.01_kernel_poly.realrank', (0.5, 0.294017094017094)),
#  ('steam_075_0.25_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_025_1_model_svm_C_0.01_kernel_poly.realrank',
#   (0.5, 0.294017094017094)),
#  ('steam_025_0.5_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_075_1_model_svm_C_0.01_kernel_rbf.realrank',
#   (0.5, 0.294017094017094)),
#  ('steam_1_1_model_svm_C_0.01_kernel_rbf.realrank', (0.5, 0.294017094017094)),
#  ('steam_1_1_model_svm_C_0.1_kernel_poly.realrank', (0.5, 0.3649031699664611)),
#  ('steam_05_0.75_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_05_1_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_05_0_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_05_0.5_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_025_1_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_0_1_model_svm_C_0.01_kernel_rbf.realrank', (0.5, 0.294017094017094)),
#  ('steam_075_0.5_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611)),
#  ('steam_05_1_model_svm_C_0.01_kernel_rbf.realrank', (0.5, 0.294017094017094)),
#  ('steam_075_0_model_svm_C_0.1_kernel_poly.realrank',
#   (0.5, 0.3649031699664611))]

# %%
map(lambda x: x[0], tops_f1[:10])
# Out:
# ['steam_1_0.25_model_knn_nneigh_3.realrank',
#  'steam_1_0.25_model_knn_nneigh_1.realrank',
#  'steam_05_0.5_model_knn_nneigh_7.realrank',
#  'steam_0_0.5_model_lr_C_1.realrank',
#  'steam_0_0.5_model_lr_C_0.1.realrank',
#  'steam_1_0.25_model_svm_C_1_kernel_linear.realrank',
#  'steam_0_0.25_model_lr_C_0.01.realrank',
#  'steam_0_0_model_svm_C_1_kernel_poly.realrank',
#  'steam_05_0.75_model_knn_nneigh_7.realrank',
#  'steam_1_0.25_model_lr_C_0.1.realrank']

# %%
#results = [('01', 0.7029411764705882, 0.5108964697304164), ('02', 0.7035294117647058, 0.515951353911875), ('03', 0.6964705882352941, 0.5120848963392557), ('05', 0.7352941176470588, 0.5607289174558332), ('07', 0.7396078431372548, 0.5674619298406618), ('09', 0.743921568627451, 0.5543014280328182)]
#results = [('10', 0.7029411764705882, 0.5108964697304164), ('20', 0.7035294117647058, 0.515951353911875), ('50', 0.7352941176470588, 0.5607289174558332), ('70', 0.7396078431372548, 0.5674619298406618), ('90', 0.743921568627451, 0.5543014280328182)]
#results =  [('01', 0.7045098039215687, 0.5182040759058543), ('02', 0.7403921568627451, 0.5667138283111678), ('03', 0.718627450980392, 0.5451174801141333), ('05', 0.7152941176470589, 0.5312458482170512), ('07', 0.7096078431372549, 0.5192377142418323), ('09', 0.737450980392157, 0.5591873157769975)]
results =  [('10', 0.7045098039215687, 0.5182040759058543), ('30', 0.718627450980392, 0.5451174801141333), ('50', 0.7152941176470589, 0.5312458482170512), ('70', 0.7096078431372549, 0.5192377142418323), ('90', 0.737450980392157, 0.5591873157769975)]

# %%
results_ba_folds =
# Out:
# [('01', 0.7045098039215687, 0.5182040759058543),
#  ('03', 0.718627450980392, 0.5451174801141333),
#  ('05', 0.7152941176470589, 0.5312458482170512),
#  ('07', 0.7096078431372549, 0.5192377142418323),
#  ('09', 0.737450980392157, 0.5591873157769975)]

# %%
import matplotlib.pyplot as plt

xs=map(lambda x: x[0], results)
y_ba = map(lambda x: x[1], results)
y_f1 = map(lambda x: x[2], results)
y_f1
# plt.figure(figsize=(15,9))
# plt.bar()
# plt.title(modelf)
# plt.show()
# Out:
# [0.5182040759058543,
#  0.5667138283111678,
#  0.5451174801141333,
#  0.5312458482170512,
#  0.5192377142418323,
#  0.5591873157769975]
